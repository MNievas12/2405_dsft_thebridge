# %% [markdown]
# ## Ejercicio Time Series Forecast
# Para este ejercicio vamos a predecir cuál será la demanda de pasajeros de una aerolinea, para poder anticiparse a las contrataciones de personal, mantenimiento de las aeronaves y gestión de inventario y comidas.
#
# Para ello, se pide:
# 1. Carga datos (AirPassengers.csv) y representa la serie. ¿Hay seasonality? ¿Cada cuanto?
# 2. Crea en una gráfica la variable original + su media obtenida mediante una rolling window con el valor de seasonality obtenido en el apartado anterior. Tienes que usar la función rolling() del DataFrame.
# 3. Comprueba de manera estadística si la serie es o no stationary.
# 4. Aplica una transformación logarítmica sobre los datos para mejorar el proceso de transformación de tu time series a stationary. Acuérdate después del forecast de invertir la transformación.
# 5. Divide en train y test. Guarda 20 muestras para test.
# 6. Crea tu primer modelo ARIMA. Habrá varias combinaciones en función de sus hiperparámetros... Mide el MAE y RMSE del modelo en predicción. Ten en cuenta el parámetro "m" de la función ARIMA, mediante el cual se establece el seasonality.
# 7. Representa en una gráfica los datos de test y tus predicciones.
# 8. Prueba un decission tree y un random forest, a ver qué performance presentan.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. Carga datos y representa la serie

# %%
df = pd.read_csv('data/AirPassengers.csv')
df
# Out:
#            date  value
# 0    1949-01-01    112
# 1    1949-02-01    118
# 2    1949-03-01    132
# 3    1949-04-01    129
# 4    1949-05-01    121
# ..          ...    ...
# 139  1960-08-01    606
# 140  1960-09-01    508
# 141  1960-10-01    461
# 142  1960-11-01    390
# 143  1960-12-01    432
#
# [144 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    144 non-null    object
#  1   value   144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    144 non-null    datetime64[ns]
#  1   value   144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
df['date'].dt.freq
# Out:
# 'MS'

# %%
len(pd.date_range(df['date'].min(), df['date'].max(), freq=df['date'].dt.freq))
# Out:
# 144

# %%
df.set_index('date', inplace=True)

# %%
plt.figure(figsize=(20,10))
plt.plot(df)

# %% [markdown]
# ## 2. Crea en una gráfica la variable original + su media obtenida mediante una rolling window comparando el valor de seasonality obtenido en el apartado anterior

# %%
df['MA12'] = df['value'].rolling(12).mean()

# %%
plt.figure(figsize=(20,10))
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x14bd194ad50>,
#  <matplotlib.lines.Line2D at 0x14bd199bbd0>]

# %% [markdown]
# ## 3. Comprueba de manera estadística si la serie es o no stationary.

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(df['value'].values)[1]
# Out:
# 0.991880243437641

# %% [markdown]
# ## 4. Aplica una transformación logarítmica

# %%
df['value'].hist()
# Out:
# <Axes: >

# %%
np.log(df['value']).hist()
# Out:
# <Axes: >

# %%
df['value_log'] = np.log(df['value'])
df
# Out:
#             value        MA12  value_log
# date
# 1949-01-01    112         NaN   4.718499
# 1949-02-01    118         NaN   4.770685
# 1949-03-01    132         NaN   4.882802
# 1949-04-01    129         NaN   4.859812
# 1949-05-01    121         NaN   4.795791
# ...           ...         ...        ...
# 1960-08-01    606  463.333333   6.406880
# 1960-09-01    508  467.083333   6.230481
# 1960-10-01    461  471.583333   6.133398
# 1960-11-01    390  473.916667   5.966147
# 1960-12-01    432  476.166667   6.068426
#
# [144 rows x 3 columns]

# %%
# ln(112) = 4.72
# e ** 4.72 = 112

# %%
2.718 ** 4.718499
# Out:
# 111.94523358683946

# %%
np.exp(4.718499)
# Out:
# 112.00001441495039

# %%
np.log(0)
# Out:
# C:\Users\Miguel Angel\AppData\Local\Temp\ipykernel_4920\2933082444.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# -inf

# %%
np.log(0+1)
# Out:
# 0.0

# %%
np.log1p(0)
# Out:
# 0.0

# %% [markdown]
# ## 5. Divide en train y test. Guarda 20 muestras para test.

# %%
y = df[['value_log']]

# %%
len(y)
# Out:
# 144

# %%
train = y.iloc[:-20,]
test = y.iloc[-20:,]

print(train.shape)
print(test.shape)
# Out:
# (124, 1)
# (20, 1)

# %% [markdown]
# ## 6. Crea tu primer modelo ARIMA

# %%
# from pmdarima.arima import ARIMA
from pmdarima.arima import auto_arima

# %%
model = auto_arima(train, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=-225.739, Time=0.43 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=-201.351, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=-202.849, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=-204.251, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=-202.180, Time=0.02 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=-229.563, Time=0.42 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=-227.732, Time=0.33 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=-233.725, Time=0.36 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : AIC=-214.822, Time=0.22 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : AIC=-232.730, Time=0.47 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : AIC=-213.443, Time=0.52 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : AIC=-220.154, Time=0.39 sec
#
# Best model:  ARIMA(4,1,2)(0,0,0)[0] intercept
# Total fit time: 5.452 seconds

# %%
y_pred = model.predict(len(test))
y_pred
# Out:
# 1959-05-01    6.039298
# 1959-06-01    6.098859
# 1959-07-01    6.099485
# 1959-08-01    6.130574
# 1959-09-01    6.115243
# 1959-10-01    6.122256
# 1959-11-01    6.118880
# 1959-12-01    6.126630
# 1960-01-01    6.137913
# 1960-02-01    6.150824
# 1960-03-01    6.165831
# 1960-04-01    6.178082
# 1960-05-01    6.189821
# 1960-06-01    6.199414
# 1960-07-01    6.208653
# 1960-08-01    6.217722
# 1960-09-01    6.227201
# 1960-10-01    6.237266
# 1960-11-01    6.247687
# 1960-12-01    6.258357
# Freq: MS, dtype: float64

# %% [markdown]
# ## 7. Representa en una gráfica los datos de test y tus predicciones.

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(test.values, y_pred)
# Out:
# 0.12573473385117678

# %%
plt.plot(test['value_log'])
plt.plot(y_pred)

# %%
model = auto_arima(train, trace=True, m = 12, stationary=False)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,1,1)[12] intercept   : AIC=-404.047, Time=1.20 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=-290.649, Time=0.05 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=-399.417, Time=0.86 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=-353.179, Time=0.31 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=-125.472, Time=0.03 sec
#  ARIMA(2,0,2)(0,1,1)[12] intercept   : AIC=-408.709, Time=1.46 sec
#  ARIMA(2,0,2)(0,1,0)[12] intercept   : AIC=-382.319, Time=0.53 sec
#  ARIMA(2,0,2)(0,1,2)[12] intercept   : AIC=-406.712, Time=2.92 sec
#  ARIMA(2,0,2)(1,1,0)[12] intercept   : AIC=-402.095, Time=1.08 sec
#  ARIMA(2,0,2)(1,1,2)[12] intercept   : AIC=-404.699, Time=2.59 sec
#  ARIMA(1,0,2)(0,1,1)[12] intercept   : AIC=-409.957, Time=0.75 sec
#  ARIMA(1,0,2)(0,1,0)[12] intercept   : AIC=-382.628, Time=0.22 sec
#  ARIMA(1,0,2)(1,1,1)[12] intercept   : AIC=-407.392, Time=1.04 sec
#  ARIMA(1,0,2)(0,1,2)[12] intercept   : AIC=-407.822, Time=2.51 sec
#  ARIMA(1,0,2)(1,1,0)[12] intercept   : AIC=-403.422, Time=0.89 sec
#  ARIMA(1,0,2)(1,1,2)[12] intercept   : AIC=-405.579, Time=2.60 sec
#  ARIMA(0,0,2)(0,1,1)[12] intercept   : AIC=-385.348, Time=1.10 sec
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=-411.631, Time=0.76 sec
#  ARIMA(1,0,1)(0,1,0)[12] intercept   : AIC=-384.170, Time=0.18 sec
#  ARIMA(1,0,1)(1,1,1)[12] intercept   : AIC=-408.998, Time=0.93 sec
#  ARIMA(1,0,1)(0,1,2)[12] intercept   : AIC=-409.714, Time=1.80 sec
#  ARIMA(1,0,1)(1,1,0)[12] intercept   : AIC=-405.268, Time=0.78 sec
#  ARIMA(1,0,1)(1,1,2)[12] intercept   : AIC=-408.104, Time=2.75 sec
#  ARIMA(1,0,0)(0,1,1)[12] intercept   : AIC=-408.087, Time=0.40 sec
#  ARIMA(2,0,1)(0,1,1)[12] intercept   : AIC=-410.728, Time=0.62 sec
#  ARIMA(0,0,0)(0,1,1)[12] intercept   : AIC=-300.825, Time=0.16 sec
#  ARIMA(2,0,0)(0,1,1)[12] intercept   : AIC=-412.378, Time=0.98 sec
#  ARIMA(2,0,0)(0,1,0)[12] intercept   : AIC=-385.056, Time=0.34 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=-405.301, Time=0.53 sec
#  ARIMA(2,0,0)(0,1,2)[12] intercept   : AIC=-410.435, Time=1.86 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=-405.874, Time=0.74 sec
#  ARIMA(2,0,0)(1,1,2)[12] intercept   : AIC=-408.716, Time=2.13 sec
#  ARIMA(3,0,0)(0,1,1)[12] intercept   : AIC=-410.666, Time=0.96 sec
#  ARIMA(3,0,1)(0,1,1)[12] intercept   : AIC=-408.760, Time=1.08 sec
#  ARIMA(2,0,0)(0,1,1)[12]             : AIC=-405.925, Time=0.71 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[12] intercept
# Total fit time: 37.878 seconds

# %%
y_pred = model.predict(len(test))
print(mean_absolute_error(test.values, y_pred))
plt.plot(test['value_log'])
plt.plot(y_pred)
# Out:
# 0.02690005525936794

# %%
np.exp(y_pred)
# Out:
# 1959-05-01    410.166428
# 1959-06-01    487.604335
# 1959-07-01    548.764023
# 1959-08-01    555.328554
# 1959-09-01    469.537513
# 1959-10-01    413.109352
# 1959-11-01    361.424473
# 1959-12-01    401.364131
# 1960-01-01    419.120229
# 1960-02-01    399.615803
# 1960-03-01    468.308050
# 1960-04-01    456.876018
# 1960-05-01    471.637354
# 1960-06-01    559.565402
# 1960-07-01    628.490371
# 1960-08-01    634.933676
# 1960-09-01    536.037879
# 1960-10-01    470.997598
# 1960-11-01    411.593689
# 1960-12-01    456.613263
# Freq: MS, dtype: float64

# %%
plt.plot(np.exp(test['value_log']))
plt.plot(np.exp(y_pred))

# %%
print(mean_absolute_error(np.exp(test.values), np.exp(y_pred)))
# Out:
# 12.774711184062744

# %% [markdown]
# ## 8. Prueba otros modelos supervisados, a ver qué performance presentan.

# %%
for i in range(1,13):
    df['t-'+str(i)] = df['value_log'].shift(i)

df.dropna(inplace=True)
df
# Out:
#             value        MA12  value_log       t-1       t-2       t-3  \
# date
# 1950-01-01    115  126.916667   4.744932  4.770685  4.644391  4.779123
# 1950-02-01    126  127.583333   4.836282  4.744932  4.770685  4.644391
# 1950-03-01    141  128.333333   4.948760  4.836282  4.744932  4.770685
# 1950-04-01    135  128.833333   4.905275  4.948760  4.836282  4.744932
# 1950-05-01    125  129.166667   4.828314  4.905275  4.948760  4.836282
# ...           ...         ...        ...       ...       ...       ...
# 1960-08-01    606  463.333333   6.406880  6.432940  6.282267  6.156979
# 1960-09-01    508  467.083333   6.230481  6.406880  6.432940  6.282267
# 1960-10-01    461  471.583333   6.133398  6.230481  6.406880  6.432940
# 1960-11-01    390  473.916667   5.966147  6.133398  6.230481  6.406880
# 1960-12-01    432  476.166667   6.068426  5.966147  6.133398  6.230481
#
#                  t-4       t-5       t-6       t-7       t-8       t-9  \
# date
# 1950-01-01  4.912655  4.997212  4.997212  4.905275  4.795791  4.859812
# 1950-02-01  4.779123  4.912655  4.997212  4.997212  4.905275  4.795791
# 1950-03-01  4.644391  4.779123  4.912655  4.997212  4.997212  4.905275
# 1950-04-01  4.770685  4.644391  4.779123  4.912655  4.997212  4.997212
# 1950-05-01  4.744932  4.770685  4.644391  4.779123  4.912655  4.997212
# ...              ...       ...       ...       ...       ...       ...
# 1960-08-01  6.133398  6.037871  5.968708  6.033086  6.003887  5.891644
# 1960-09-01  6.156979  6.133398  6.037871  5.968708  6.033086  6.003887
# 1960-10-01  6.282267  6.156979  6.133398  6.037871  5.968708  6.033086
# 1960-11-01  6.432940  6.282267  6.156979  6.133398  6.037871  5.968708
# 1960-12-01  6.406880  6.432940  6.282267  6.156979  6.133398  6.037871
#
#                 t-10      t-11      t-12
# date
# 1950-01-01  4.882802  4.770685  4.718499
# 1950-02-01  4.859812  4.882802  4.770685
# 1950-03-01  4.795791  4.859812  4.882802
# 1950-04-01  4.905275  4.795791  4.859812
# 1950-05-01  4.997212  4.905275  4.795791
# ...              ...       ...       ...
# 1960-08-01  6.008813  6.137727  6.326149
# 1960-09-01  5.891644  6.008813  6.137727
# 1960-10-01  6.003887  5.891644  6.008813
# 1960-11-01  6.033086  6.003887  5.891644
# 1960-12-01  5.968708  6.033086  6.003887
#
# [132 rows x 15 columns]

# %%
X = df.drop(columns=['value', 'value_log'])
y = df['value_log']

# %%
X_train = X.iloc[:-20,]
y_train = y.iloc[:-20,]
X_test = X.iloc[-20:,]
y_test = y.iloc[-20:,]

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (112, 13)
# (20, 13)
# (112,)
# (20,)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(max_depth=5)

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

print(mean_absolute_error(y_test, y_pred))

plt.plot(y_test.values)
plt.plot(y_pred)
# Out:
# 0.0822828566020282

# %%
X.columns
# Out:
# Index(['MA12', 't-1', 't-2', 't-3', 't-4', 't-5', 't-6', 't-7', 't-8', 't-9',
#        't-10', 't-11', 't-12'],
#       dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.03799893, 0.0943198 , 0.00174696, 0.00348131, 0.00138706,
#        0.00123464, 0.00092634, 0.00129006, 0.00157277, 0.00164619,
#        0.00187363, 0.03228302, 0.82023929])

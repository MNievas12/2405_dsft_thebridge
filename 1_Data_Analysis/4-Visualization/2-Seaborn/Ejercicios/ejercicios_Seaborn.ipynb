# %% [markdown]
# # Ejercicios de Seaborn

# %%
# 1. Importa pandas, pyplot y seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame

# %%
df = pd.read_csv("data/Pokemon.csv", encoding="utf-8", index_col=0)
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  151.00000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean   407.07947   64.211921   72.549669   68.225166   67.139073   66.019868
# std     99.74384   28.590117   26.596162   26.916704   28.534199   24.197926
# min    195.00000   10.000000    5.000000    5.000000   15.000000   20.000000
# 25%    320.00000   45.000000   51.000000   50.000000   45.000000   49.000000
# 50%    405.00000   60.000000   70.000000   65.000000   65.000000   65.000000
# 75%    490.00000   80.000000   90.000000   84.000000   87.500000   80.000000
# max    680.00000  250.000000  134.000000  180.000000  154.000000  125.000000
#
#             Speed       Stage
# count  151.000000  151.000000
# mean    68.933775    1.582781
# std     26.746880    0.676832
# min     15.000000    1.000000
# 25%     46.500000    1.000000
# 50%     70.000000    1.000000
# 75%     90.000000    2.000000
# max    140.000000    3.000000

# %%
# df[df['Name'].str.contains("Nidoran")]

# %%
# 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados

# %%
df.head(9)
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
# 6   Charizard   Fire  Flying    534  78      84       78      109       85
# 7    Squirtle  Water     NaN    314  44      48       65       50       64
# 8   Wartortle  Water     NaN    405  59      63       80       65       80
# 9   Blastoise  Water     NaN    530  79      83      100       85      105
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False
# 6    100      3      False
# 7     43      1      False
# 8     58      2      False
# 9     78      3      False

# %%
# 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal
# Pasa el DataFrame como argumento del método en el parámetro llamado data

# %%
sns.lmplot(data=df, x="Attack", y="Defense");

# %%
# 6. No queremos ver la línea recta de la regresión lineal.
# prueba a añadir fit_reg a falso

# %%
sns.lmplot(data=df, x="Attack", y="Defense", fit_reg=False);

# %%
# 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue)
# Que el hue sea el Stage

# %%
sns.lmplot(data=df, x="Attack", y="Defense", fit_reg=False, hue="Stage");

# %%
sns.lmplot(data=df, x="Attack", y="Defense", fit_reg=False, hue="Legendary");

# %%
# 8. Limita el eje x entre 20 y 100

# %%
sns.lmplot(data=df, x="Attack", y="Defense", fit_reg=False, hue="Legendary");
plt.xlim(20,100)
# Out:
# (20.0, 100.0)

# %%
# 9. Dibuja un diagrama de cajas con el dataframe

# %%
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
sns.boxplot(data=df[['Total']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df.drop(columns=["Total","Stage","Legendary"]))
# Out:
# <Axes: >

# %%
# 10. No nos interesan las columnas Total, Stage ni Legendary
# Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
sns.boxplot(data=df.loc[:,"HP":"Speed"])
# Out:
# <Axes: >

# %%
# 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon'], dtype=object)

# %%
df['Type 1'].nunique()
# Out:
# 15

# %%
df['Type 1'].value_counts()
# Out:
# Water       28
# Normal      22
# Poison      14
# Grass       12
# Fire        12
# Bug         12
# Electric     9
# Rock         9
# Ground       8
# Psychic      8
# Fighting     7
# Ghost        3
# Dragon       3
# Fairy        2
# Ice          2
# Name: Type 1, dtype: int64

# %%
plt.pie(df['Type 1'].value_counts(), labels=df['Type 1'].value_counts().index, autopct="%1.1f");

# %%
df['Type 2'].value_counts()
# Out:
# Poison      19
# Flying      19
# Ground       6
# Psychic      6
# Water        4
# Fairy        3
# Ice          3
# Grass        2
# Steel        2
# Rock         2
# Fighting     1
# Name: Type 2, dtype: int64

# %%
df.groupby(["Type 1", "Type 2"])['Name'].count()
# Out:
# Type 1    Type 2
# Bug       Flying      2
#           Grass       2
#           Poison      5
# Dragon    Flying      1
# Electric  Flying      1
#           Steel       2
# Fire      Flying      2
# Ghost     Poison      3
# Grass     Poison      9
#           Psychic     2
# Ground    Rock        2
# Ice       Flying      1
#           Psychic     1
# Normal    Fairy       2
#           Flying      8
# Poison    Flying      2
#           Ground      2
# Psychic   Fairy       1
# Rock      Flying      1
#           Ground      4
#           Water       4
# Water     Fighting    1
#           Flying      1
#           Ice         3
#           Poison      2
#           Psychic     3
# Name: Name, dtype: int64

# %%
df['Type 2'].fillna("No type", inplace=True)

# %%
df.groupby(["Type 1", "Type 2"])['Name'].count()
# Out:
# Type 1    Type 2
# Bug       Flying       2
#           Grass        2
#           No type      3
#           Poison       5
# Dragon    Flying       1
#           No type      2
# Electric  Flying       1
#           No type      6
#           Steel        2
# Fairy     No type      2
# Fighting  No type      7
# Fire      Flying       2
#           No type     10
# Ghost     Poison       3
# Grass     No type      1
#           Poison       9
#           Psychic      2
# Ground    No type      6
#           Rock         2
# Ice       Flying       1
#           Psychic      1
# Normal    Fairy        2
#           Flying       8
#           No type     12
# Poison    Flying       2
#           Ground       2
#           No type     10
# Psychic   Fairy        1
#           No type      7
# Rock      Flying       1
#           Ground       4
#           Water        4
# Water     Fighting     1
#           Flying       1
#           Ice          3
#           No type     18
#           Poison       2
#           Psychic      3
# Name: Name, dtype: int64

# %%
df[(df['Type 1'] == "Poison") | (df['Type 2'] == "Poison")]
# Out:
#            Name  Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur   Grass   Poison    318   45      49       49       65
# 2       Ivysaur   Grass   Poison    405   60      62       63       80
# 3      Venusaur   Grass   Poison    525   80      82       83      100
# 13       Weedle     Bug   Poison    195   40      35       30       20
# 14       Kakuna     Bug   Poison    205   45      25       50       25
# 15     Beedrill     Bug   Poison    395   65      90       40       45
# 23        Ekans  Poison  No type    288   35      60       44       40
# 24        Arbok  Poison  No type    438   60      85       69       65
# 29   Nidoran���  Poison  No type    275   55      47       52       40
# 30     Nidorina  Poison  No type    365   70      62       67       55
# 31    Nidoqueen  Poison   Ground    505   90      92       87       75
# 32   Nidoran���  Poison  No type    273   46      57       40       40
# 33     Nidorino  Poison  No type    365   61      72       57       55
# 34     Nidoking  Poison   Ground    505   81     102       77       85
# 41        Zubat  Poison   Flying    245   40      45       35       30
# 42       Golbat  Poison   Flying    455   75      80       70       65
# 43       Oddish   Grass   Poison    320   45      50       55       75
# 44        Gloom   Grass   Poison    395   60      65       70       85
# 45    Vileplume   Grass   Poison    490   75      80       85      110
# 48      Venonat     Bug   Poison    305   60      55       50       40
# 49     Venomoth     Bug   Poison    450   70      65       60       90
# 69   Bellsprout   Grass   Poison    300   50      75       35       70
# 70   Weepinbell   Grass   Poison    390   65      90       50       85
# 71   Victreebel   Grass   Poison    490   80     105       65      100
# 72    Tentacool   Water   Poison    335   40      40       35       50
# 73   Tentacruel   Water   Poison    515   80      70       65       80
# 88       Grimer  Poison  No type    325   80      80       50       40
# 89          Muk  Poison  No type    500  105     105       75       65
# 92       Gastly   Ghost   Poison    310   30      35       30      100
# 93      Haunter   Ghost   Poison    405   45      50       45      115
# 94       Gengar   Ghost   Poison    500   60      65       60      130
# 109     Koffing  Poison  No type    340   40      65       95       60
# 110     Weezing  Poison  No type    490   65      90      120       85
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 13        20     50      1      False
# 14        25     35      2      False
# 15        80     75      3      False
# 23        54     55      1      False
# 24        79     80      2      False
# 29        40     41      1      False
# 30        55     56      2      False
# 31        85     76      3      False
# 32        40     50      1      False
# 33        55     65      2      False
# 34        75     85      3      False
# 41        40     55      1      False
# 42        75     90      2      False
# 43        65     30      1      False
# 44        75     40      2      False
# 45        90     50      3      False
# 48        55     45      1      False
# 49        75     90      2      False
# 69        30     40      1      False
# 70        45     55      2      False
# 71        70     70      3      False
# 72       100     70      1      False
# 73       120    100      2      False
# 88        50     25      1      False
# 89       100     50      2      False
# 92        35     80      1      False
# 93        55     95      2      False
# 94        75    110      3      False
# 109       45     35      1      False
# 110       70     60      2      False

# %%
import numpy as np

# %%
df['Poison'] = np.where((df['Type 1'] == "Poison") | (df['Type 2'] == "Poison"), 1, 0)
df
# Out:
#            Name   Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass   Poison    318   45      49       49       65
# 2       Ivysaur    Grass   Poison    405   60      62       63       80
# 3      Venusaur    Grass   Poison    525   80      82       83      100
# 4    Charmander     Fire  No type    309   39      52       43       60
# 5    Charmeleon     Fire  No type    405   58      64       58       80
# ..          ...      ...      ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon  No type    300   41      64       45       50
# 148   Dragonair   Dragon  No type    420   61      84       65       70
# 149   Dragonite   Dragon   Flying    600   91     134       95      100
# 150      Mewtwo  Psychic  No type    680  106     110       90      154
# 151         Mew  Psychic  No type    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary  Poison
# #
# 1         65     45      1      False       1
# 2         80     60      2      False       1
# 3        100     80      3      False       1
# 4         50     65      1      False       0
# 5         65     80      2      False       0
# ..       ...    ...    ...        ...     ...
# 147       50     50      1      False       0
# 148       70     70      2      False       0
# 149      100     80      3      False       0
# 150       90    130      1       True       0
# 151      100    100      1      False       0
#
# [151 rows x 13 columns]

# %%
# 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water'

# %%
df_gfw = df[df['Type 1'].isin(["Grass", "Fire", "Water"])]
df_gfw
# Out:
#            Name Type 1    Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur  Grass    Poison    318   45      49       49       65
# 2       Ivysaur  Grass    Poison    405   60      62       63       80
# 3      Venusaur  Grass    Poison    525   80      82       83      100
# 4    Charmander   Fire   No type    309   39      52       43       60
# 5    Charmeleon   Fire   No type    405   58      64       58       80
# 6     Charizard   Fire    Flying    534   78      84       78      109
# 7      Squirtle  Water   No type    314   44      48       65       50
# 8     Wartortle  Water   No type    405   59      63       80       65
# 9     Blastoise  Water   No type    530   79      83      100       85
# 37       Vulpix   Fire   No type    299   38      41       40       50
# 38    Ninetales   Fire   No type    505   73      76       75       81
# 43       Oddish  Grass    Poison    320   45      50       55       75
# 44        Gloom  Grass    Poison    395   60      65       70       85
# 45    Vileplume  Grass    Poison    490   75      80       85      110
# 54      Psyduck  Water   No type    320   50      52       48       65
# 55      Golduck  Water   No type    500   80      82       78       95
# 58    Growlithe   Fire   No type    350   55      70       45       70
# 59     Arcanine   Fire   No type    555   90     110       80      100
# 60      Poliwag  Water   No type    300   40      50       40       40
# 61    Poliwhirl  Water   No type    385   65      65       65       50
# 62    Poliwrath  Water  Fighting    510   90      95       95       70
# 69   Bellsprout  Grass    Poison    300   50      75       35       70
# 70   Weepinbell  Grass    Poison    390   65      90       50       85
# 71   Victreebel  Grass    Poison    490   80     105       65      100
# 72    Tentacool  Water    Poison    335   40      40       35       50
# 73   Tentacruel  Water    Poison    515   80      70       65       80
# 77       Ponyta   Fire   No type    410   50      85       55       65
# 78     Rapidash   Fire   No type    500   65     100       70       80
# 79     Slowpoke  Water   Psychic    315   90      65       65       40
# 80      Slowbro  Water   Psychic    490   95      75      110      100
# 86         Seel  Water   No type    325   65      45       55       45
# 87      Dewgong  Water       Ice    475   90      70       80       70
# 90     Shellder  Water   No type    305   30      65      100       45
# 91     Cloyster  Water       Ice    525   50      95      180       85
# 98       Krabby  Water   No type    325   30     105       90       25
# 99      Kingler  Water   No type    475   55     130      115       50
# 102   Exeggcute  Grass   Psychic    325   60      40       80       60
# 103   Exeggutor  Grass   Psychic    520   95      95       85      125
# 114     Tangela  Grass   No type    435   65      55      115      100
# 116      Horsea  Water   No type    295   30      40       70       70
# 117      Seadra  Water   No type    440   55      65       95       95
# 118     Goldeen  Water   No type    320   45      67       60       35
# 119     Seaking  Water   No type    450   80      92       65       65
# 120      Staryu  Water   No type    340   30      45       55       70
# 121     Starmie  Water   Psychic    520   60      75       85      100
# 126      Magmar   Fire   No type    495   65      95       57      100
# 129    Magikarp  Water   No type    200   20      10       55       15
# 130    Gyarados  Water    Flying    540   95     125       79       60
# 131      Lapras  Water       Ice    535  130      85       80       85
# 134    Vaporeon  Water   No type    525  130      65       60      110
# 136     Flareon   Fire   No type    525   65     130       60       95
# 146     Moltres   Fire    Flying    580   90     100       90      125
#
#      Sp. Def  Speed  Stage  Legendary  Poison
# #
# 1         65     45      1      False       1
# 2         80     60      2      False       1
# 3        100     80      3      False       1
# 4         50     65      1      False       0
# 5         65     80      2      False       0
# 6         85    100      3      False       0
# 7         64     43      1      False       0
# 8         80     58      2      False       0
# 9        105     78      3      False       0
# 37        65     65      1      False       0
# 38       100    100      2      False       0
# 43        65     30      1      False       1
# 44        75     40      2      False       1
# 45        90     50      3      False       1
# 54        50     55      1      False       0
# 55        80     85      2      False       0
# 58        50     60      1      False       0
# 59        80     95      2      False       0
# 60        40     90      1      False       0
# 61        50     90      2      False       0
# 62        90     70      3      False       0
# 69        30     40      1      False       1
# 70        45     55      2      False       1
# 71        70     70      3      False       1
# 72       100     70      1      False       1
# 73       120    100      2      False       1
# 77        65     90      1      False       0
# 78        80    105      2      False       0
# 79        40     15      1      False       0
# 80        80     30      2      False       0
# 86        70     45      1      False       0
# 87        95     70      2      False       0
# 90        25     40      1      False       0
# 91        45     70      2      False       0
# 98        25     50      1      False       0
# 99        50     75      2      False       0
# 102       45     40      1      False       0
# 103       65     55      2      False       0
# 114       40     60      1      False       0
# 116       25     60      1      False       0
# 117       45     85      2      False       0
# 118       50     63      1      False       0
# 119       80     68      2      False       0
# 120       55     85      1      False       0
# 121       85    115      2      False       0
# 126       85     93      1      False       0
# 129       20     80      1      False       0
# 130      100     81      2      False       0
# 131       95     60      1      False       0
# 134       95     65      2      False       0
# 136      110     65      2      False       0
# 146       85     90      1       True       0

# %%
# 13. Usa un estilo 'whitegrid'

# %%
sns.set_style("whitegrid")

# %%
# 14. Pinta diagramas de violín con el DataFrame filtrado por los 3 tipos

# %%
sns.violinplot(data=df_gfw, x="Type 1", y="Attack")
# Out:
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'

# %%
lista_colores = ['#78C850', '#F08030',  '#6890F0']

# %%
# 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette)

# %%
sns.violinplot(data=df_gfw, x="Type 1", y="Attack", palette=lista_colores)
# Out:
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos.
# Para ver esto, usamos el swarmplot.
# Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin

# %%
sns.swarmplot(x="Type 1", y="Attack", data=df_gfw, palette=lista_colores)
# Out:
# C:\Users\Miguel Angel\AppData\Local\Temp\ipykernel_8248\2701536884.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x="Type 1", y="Attack", data=df_gfw, palette=lista_colores)
# <Axes: xlabel='Type 1', ylabel='Attack'>

# %%
# 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. 
# Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una transparencia de 0.9 en el swarmplot
# Pon un título con pyplot (como siempre)

# %%
sns.violinplot(data=df_gfw, x="Type 1", y="Attack", palette=lista_colores, inner=None)
sns.swarmplot(x="Type 1", y="Attack", data=df_gfw, color="k", alpha=0.9)
plt.ylim(-20, 180)
plt.title("Distribución ataque pokemons planta, fuego y agua")
# Out:
# Text(0.5, 1.0, 'Distribución ataque pokemons planta, fuego y agua')

# %%
# 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual
# * qué nombres de columnas del dataframe pasan a ser una columna nueva
# * cómo queremos llamar esas nuevas columnas

# Primero recuerda el Dataframe df_grass_fire_water con las primeras 5 filas

# %%
help(pd.melt)
# Out:
# Help on function melt in module pandas.core.reshape.melt:
#
# melt(frame: 'DataFrame', id_vars=None, value_vars=None, var_name=None, value_name='value', col_level=None, ignore_index: 'bool' = True) -> 'DataFrame'
#     Unpivot a DataFrame from wide to long format, optionally leaving identifiers set.
#
#     This function is useful to massage a DataFrame into a format where one
#     or more columns are identifier variables (`id_vars`), while all other
#     columns, considered measured variables (`value_vars`), are "unpivoted" to
#     the row axis, leaving just two non-identifier columns, 'variable' and
#     'value'.
#
#     Parameters
#     ----------
#     id_vars : tuple, list, or ndarray, optional
#         Column(s) to use as identifier variables.
#     value_vars : tuple, list, or ndarray, optional
#         Column(s) to unpivot. If not specified, uses all columns that
#         are not set as `id_vars`.
#     var_name : scalar
#         Name to use for the 'variable' column. If None it uses
#         ``frame.columns.name`` or 'variable'.
#     value_name : scalar, default 'value'
#         Name to use for the 'value' column.
#     col_level : int or str, optional
#         If columns are a MultiIndex then use this level to melt.
#     ignore_index : bool, default True
#         If True, original index is ignored. If False, the original index is retained.
#         Index labels will be repeated as necessary.
#
#         .. versionadded:: 1.1.0
#
#     Returns
#     -------
#     DataFrame
#         Unpivoted DataFrame.
#
#     See Also
#     --------
#     DataFrame.melt : Identical method.
#     pivot_table : Create a spreadsheet-style pivot table as a DataFrame.
#     DataFrame.pivot : Return reshaped DataFrame organized
#         by given index / column values.
#     DataFrame.explode : Explode a DataFrame from list-like
#             columns to long format.
#
#     Notes
#     -----
#     Reference :ref:`the user guide <reshaping.melt>` for more examples.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({'A': {0: 'a', 1: 'b', 2: 'c'},
#     ...                    'B': {0: 1, 1: 3, 2: 5},
#     ...                    'C': {0: 2, 1: 4, 2: 6}})
#     >>> df
#        A  B  C
#     0  a  1  2
#     1  b  3  4
#     2  c  5  6
#
#     >>> pd.melt(df, id_vars=['A'], value_vars=['B'])
#        A variable  value
#     0  a        B      1
#     1  b        B      3
#     2  c        B      5
#
#     >>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'])
#        A variable  value
#     0  a        B      1
#     1  b        B      3
#     2  c        B      5
#     3  a        C      2
#     4  b        C      4
#     5  c        C      6
#
#     The names of 'variable' and 'value' columns can be customized:
#
#     >>> pd.melt(df, id_vars=['A'], value_vars=['B'],
#     ...         var_name='myVarname', value_name='myValname')
#        A myVarname  myValname
#     0  a         B          1
#     1  b         B          3
#     2  c         B          5
#
#     Original index values can be kept around:
#
#     >>> pd.melt(df, id_vars=['A'], value_vars=['B', 'C'], ignore_index=False)
#        A variable  value
#     0  a        B      1
#     1  b        B      3
#     2  c        B      5
#     0  a        C      2
#     1  b        C      4
#     2  c        C      6
#
#     If you have multi-index columns:
#
#     >>> df.columns = [list('ABC'), list('DEF')]
#     >>> df
#        A  B  C
#        D  E  F
#     0  a  1  2
#     1  b  3  4
#     2  c  5  6
#
#     >>> pd.melt(df, col_level=0, id_vars=['A'], value_vars=['B'])
#        A variable  value
#     0  a        B      1
#     1  b        B      3
#     2  c        B      5
#
#     >>> pd.melt(df, id_vars=[('A', 'D')], value_vars=[('B', 'E')])
#       (A, D) variable_0 variable_1  value
#     0      a          B          E      1
#     1      b          B          E      3
#     2      c          B          E      5

# %%
# 20. Queremos dejar igual las variables 'Name' y 'Type 1'
# Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'
# Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column')

# %%
df_gfw.columns[4:10]
# Out:
# Index(['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed'], dtype='object')

# %%
df_melted = df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=df_gfw.columns[4:10], var_name='Variable')
df_melted
# Out:
#            Name Type 1 Variable  value
# 0     Bulbasaur  Grass       HP     45
# 1       Ivysaur  Grass       HP     60
# 2      Venusaur  Grass       HP     80
# 3    Charmander   Fire       HP     39
# 4    Charmeleon   Fire       HP     58
# ..          ...    ...      ...    ...
# 307    Gyarados  Water    Speed     81
# 308      Lapras  Water    Speed     60
# 309    Vaporeon  Water    Speed     65
# 310     Flareon   Fire    Speed     65
# 311     Moltres   Fire    Speed     90
#
# [312 rows x 4 columns]

# %%
df_melted[df_melted['Name'] == "Bulbasaur"]
# Out:
#           Name Type 1 New Column  value
# 0    Bulbasaur  Grass         HP     45
# 52   Bulbasaur  Grass     Attack     49
# 104  Bulbasaur  Grass    Defense     49
# 156  Bulbasaur  Grass    Sp. Atk     65
# 208  Bulbasaur  Grass    Sp. Def     65
# 260  Bulbasaur  Grass      Speed     45

# %%
pd.pivot(df_melted, columns="Variable", values="value", index="Name")
# Out:
# Variable    Attack  Defense   HP  Sp. Atk  Sp. Def  Speed
# Name
# Arcanine       110       80   90      100       80     95
# Bellsprout      75       35   50       70       30     40
# Blastoise       83      100   79       85      105     78
# Bulbasaur       49       49   45       65       65     45
# Charizard       84       78   78      109       85    100
# Charmander      52       43   39       60       50     65
# Charmeleon      64       58   58       80       65     80
# Cloyster        95      180   50       85       45     70
# Dewgong         70       80   90       70       95     70
# Exeggcute       40       80   60       60       45     40
# Exeggutor       95       85   95      125       65     55
# Flareon        130       60   65       95      110     65
# Gloom           65       70   60       85       75     40
# Goldeen         67       60   45       35       50     63
# Golduck         82       78   80       95       80     85
# Growlithe       70       45   55       70       50     60
# Gyarados       125       79   95       60      100     81
# Horsea          40       70   30       70       25     60
# Ivysaur         62       63   60       80       80     60
# Kingler        130      115   55       50       50     75
# Krabby         105       90   30       25       25     50
# Lapras          85       80  130       85       95     60
# Magikarp        10       55   20       15       20     80
# Magmar          95       57   65      100       85     93
# Moltres        100       90   90      125       85     90
# Ninetales       76       75   73       81      100    100
# Oddish          50       55   45       75       65     30
# Poliwag         50       40   40       40       40     90
# Poliwhirl       65       65   65       50       50     90
# Poliwrath       95       95   90       70       90     70
# Ponyta          85       55   50       65       65     90
# Psyduck         52       48   50       65       50     55
# Rapidash       100       70   65       80       80    105
# Seadra          65       95   55       95       45     85
# Seaking         92       65   80       65       80     68
# Seel            45       55   65       45       70     45
# Shellder        65      100   30       45       25     40
# Slowbro         75      110   95      100       80     30
# Slowpoke        65       65   90       40       40     15
# Squirtle        48       65   44       50       64     43
# Starmie         75       85   60      100       85    115
# Staryu          45       55   30       70       55     85
# Tangela         55      115   65      100       40     60
# Tentacool       40       35   40       50      100     70
# Tentacruel      70       65   80       80      120    100
# Vaporeon        65       60  130      110       95     65
# Venusaur        82       83   80      100      100     80
# Victreebel     105       65   80      100       70     70
# Vileplume       80       85   75      110       90     50
# Vulpix          41       40   38       50       65     65
# Wartortle       63       80   59       65       80     58
# Weepinbell      90       50   65       85       45     55

# %%
# 21. Pintamos el swarmplot con el melted y entendemos la información

# %%
sns.swarmplot(x="Variable", y="value", data=df_melted, hue="Variable")
# Out:
# <Axes: xlabel='Variable', ylabel='value'>

# %%
# 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt)
# En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon

# Dodge en inglés es "esquivar", ¿qué diferencia ves?

# Usando plt 
# fija el límite del eje Y entre 0 y 200
# fija la leyenda con bbox_to_anchor en upper left. Pista: upper left es el código 2 y se usa el parámetro loc.

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x="Variable", y="value", data=df_melted, hue="Type 1", palette=lista_colores, dodge=True);
plt.ylim(0,200)
plt.legend(loc="upper left") # bbox_to_anchor=(0.15,1)

# %%
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño
# Lo importante es que Seaborn y Pyplot conviven bien juntos

# %%
# 23. Mapas de calor
# Calcula las correlaciones del primer DataFrame original df
# Pista: las correlaciones se calculan con el método corr()
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
df.corr(numeric_only=True)
# Out:
#               Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total      1.000000  0.576591  0.670939  0.508694  0.680745  0.774383
# HP         0.576591  1.000000  0.306768  0.119782  0.236649  0.490978
# Attack     0.670939  0.306768  1.000000  0.491965  0.146312  0.369069
# Defense    0.508694  0.119782  0.491965  1.000000  0.187569  0.139912
# Sp. Atk    0.680745  0.236649  0.146312  0.187569  1.000000  0.522907
# Sp. Def    0.774383  0.490978  0.369069  0.139912  0.522907  1.000000
# Speed      0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656
# Stage      0.504224  0.249207  0.361321  0.270861  0.391712  0.358308
# Legendary  0.328412  0.172441  0.147486  0.141576  0.334159  0.215314
# Poison    -0.131638 -0.068044 -0.099229 -0.175278  0.027842 -0.036981
#
#               Speed     Stage  Legendary    Poison
# Total      0.506950  0.504224   0.328412 -0.131638
# HP        -0.040939  0.249207   0.172441 -0.068044
# Attack     0.194701  0.361321   0.147486 -0.099229
# Defense   -0.053252  0.270861   0.141576 -0.175278
# Sp. Atk    0.411516  0.391712   0.334159  0.027842
# Sp. Def    0.392656  0.358308   0.215314 -0.036981
# Speed      1.000000  0.240042   0.199969 -0.139352
# Stage      0.240042  1.000000  -0.142508  0.184538
# Legendary  0.199969 -0.142508   1.000000 -0.087234
# Poison    -0.139352  0.184538  -0.087234  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), vmin=-1, vmax=1, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x="Total", y="Sp. Def")
# Out:
# <Axes: xlabel='Total', ylabel='Sp. Def'>

# %%
df.corr(numeric_only=True)['Total'][1:].sort_values(ascending=False).plot(kind="bar")
# Out:
# <Axes: >

# %%
# ¿la correlación entre qué valores se encuentra?
# la autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# Encuentra dos variables que veas que están fuertemente relacionadas según la correlación
# Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías? (ML)

# %%
correlaciones = np.abs(df.corr(numeric_only=True)['Total'])
correlaciones[correlaciones != 1].max()
# Out:
# 0.7743825436542867

# %%
correlaciones = np.abs(df.corr(numeric_only=True)['Total'])
correlaciones.min()
# Out:
# 0.1316376548075021

# %%
# 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original

# %%
sns.displot(df['Defense'], kde=True)

# %%
# 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original
# Usa un sns.countplot
# Usa plt.xticks y gira las etiquetas

# %%
sns.countplot(x="Type 1", data=df, order = df['Type 1'].value_counts().index)
plt.xticks(rotation = -45);

# %%
# 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios
# y divide los colores según el Type 2

# %%
df.loc[df['Type 2']=="No type",'Type 2'] = np.nan

# %%
df['Type 2'].fillna("No type", inplace=True)

# %%
df
# Out:
#            Name   Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# #
# 1     Bulbasaur    Grass   Poison    318   45      49       49       65
# 2       Ivysaur    Grass   Poison    405   60      62       63       80
# 3      Venusaur    Grass   Poison    525   80      82       83      100
# 4    Charmander     Fire  No type    309   39      52       43       60
# 5    Charmeleon     Fire  No type    405   58      64       58       80
# ..          ...      ...      ...    ...  ...     ...      ...      ...
# 147     Dratini   Dragon  No type    300   41      64       45       50
# 148   Dragonair   Dragon  No type    420   61      84       65       70
# 149   Dragonite   Dragon   Flying    600   91     134       95      100
# 150      Mewtwo  Psychic  No type    680  106     110       90      154
# 151         Mew  Psychic  No type    600  100     100      100      100
#
#      Sp. Def  Speed  Stage  Legendary
# #
# 1         65     45      1      False
# 2         80     60      2      False
# 3        100     80      3      False
# 4         50     65      1      False
# 5         65     80      2      False
# ..       ...    ...    ...        ...
# 147       50     50      1      False
# 148       70     70      2      False
# 149      100     80      3      False
# 150       90    130      1       True
# 151      100    100      1      False
#
# [151 rows x 12 columns]

# %%
chart = sns.catplot(x="Type 1", y="Defense", data=df, hue="Type 2", col="Legendary")
chart.set_xticklabels(rotation=-45)

# %%
# 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque.
# Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
sns.kdeplot(x=df['Attack'], y=df['Defense'])
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %%
# 28. Pinta una distribución de probabilidad conjunta con jointplot, pintando la defensa respecto al ataque del DataFrame original

# %%
sns.jointplot(x=df['Attack'], y=df['Defense'], kind="kde")
